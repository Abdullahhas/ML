# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('social_network_ads.csv')

dataset.drop(columns=['EstimatedSalary'] , inplace=True)

# %%
dataset.head(3)
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='Age' , y='Purchased' , data=dataset)
plt.show()

# %%
x = dataset[['Age']]
y = dataset['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.20 ,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test , y_test)
# Out:
# 0.75

# %%
lr.predict([[19]])
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x='Age' , y='Purchased' , data=dataset)
sns.lineplot(x="Age" , y=lr.predict(x) ,data=dataset ,c ='red')
plt.show()
