# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('knn.csv')
dataset.head(3)
# Out:
#    Age  Experience  Salary
# 0   21           0   20000
# 1   25           2   28000
# 2   30           5   40000

# %%
sns.scatterplot(x='Age' , y = 'Experience' , data=dataset , hue='Salary')
plt.show()

# %%
x = dataset.iloc[: , :-1]
y = dataset['Salary']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor(n_neighbors=3)

# %%
knn.fit(x_train , y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knn.score(x_test , y_test)*100
# Out:
# 95.3360768175583

# %%
for i in range(1,7):
    knn1= KNeighborsRegressor(n_neighbors=i)
    knn1.fit(x_train , y_train)
    print(i,knn1.score(x_train , y_train)*100 , knn1.score(x_test , y_test)*100)
# Out:
# 1 100.0 55.55555555555556
# 2 96.23655913978494 -24.691358024691358
# 3 92.9660753190165 95.3360768175583
# 4 83.36721785488389 -7.716049382716039
# 5 70.36089274419446 -118.56790123456791
# 6 56.34519040591148 -527.297668038409
